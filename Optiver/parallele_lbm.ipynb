# %%
# %load_ext autoreload
# %autoreload 2
import gc  
import os  
import joblib
import time  
import warnings 
from itertools import combinations  
from warnings import simplefilter 
import lightgbm as lgb  
from lightgbm import Booster
if hasattr(Booster, '__deepcopy__'):
    del Booster.__deepcopy__
from copy import deepcopy
import numpy as np  
import pandas as pd  
from sklearn.metrics import mean_absolute_error 
from sklearn.model_selection import KFold, TimeSeriesSplit  
import polars as pl
from utils_kgl.utils import *
from utils_kgl.model_selection import *
from utils_kgl.processing import *
from datetime import datetime
from tqdm import tqdm
warnings.filterwarnings("ignore")
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)



# Setup
with_gpu = False
is_local = True
path = 'data/optiver-trading-at-the-close/' if is_local else '/kaggle/input/optiver-trading-at-the-close/'

model_save_path = 'models'
if not os.path.exists(model_save_path):
    os.makedirs(model_save_path)

# Do we split data in train and test
is_testing = True
split_day = 400
save_test_model = True

# Cross validation
is_CV = False
save_model_CV = True

# Final model
is_train_final = True
save_final_model = True

# %%
# Data Loading
df = pd.read_csv(path + "train.csv")
df = df.dropna(subset=["target"])
df.reset_index(drop=True, inplace=True)
df = reduce_mem_usage(df)

if is_testing:
    df_train = df[df["date_id"] <= split_day]
    df_test = df[df["date_id"] > split_day]
    print("Testing mode")
    print(f"train : {df_train.shape}, valid : {df_test.shape}")
    
else:
    df_train = df
    print(f"Dataset : {df_train.shape}")
    print("Online mode")
# Out:
# Testing mode
# train : (4357893, 17), valid : (879999, 17)

# %% [markdown]
# # **Model Training**

# %%
# Model Params
lgb_params = {
     "objective": "mae",
    "n_estimators": 6000,
    # "n_estimators": 10,
    "num_leaves": 256,
    # "num_leaves": 16,
    "subsample": 0.6,
    "colsample_bytree": 0.8,
#         "learning_rate": 0.00871,
    "learning_rate": 0.01,
    'max_depth': 11,
    # 'max_depth': 4,
    
    "n_jobs": -1,
    "verbosity": -1,
    "importance_type": "gain",
#         "reg_alpha": 0.1,
    "reg_alpha": 0.2,
    "reg_lambda": 3.25
}

if with_gpu:
    lgb_params['device']='gpu'


prepro = Preprocessing()
model = lgb.LGBMRegressor(**lgb_params)

model_base_name = f'lgb_para_{get_name_from_param_dict(lgb_params)}'
model_filename_CV = os.path.join(model_save_path, f'{model_base_name}_CV.pkl')
model_filename_test = os.path.join(model_save_path, f'{model_base_name}_test.pkl')
model_filename_final = os.path.join(model_save_path, f'{model_base_name}_final.pkl')

# %%
# Cross validation
if is_CV:
    date_ids = df_train['date_id'].values
    y_train = df_train['target']
    num_folds = 5
    gap = 5
    prepro_CV = deepcopy(prepro)
    scores, modelsCV, preprosCV = scoreCV(df_train, y_train, date_ids,model, prepro_CV, num_folds, gap, verbose = True)

    if save_model_CV:
        joblib.dump((modelsCV, preprosCV), model_filename_CV)

# %%
import math
def random_split_date(df, frac=0.8):
    date_id = np.unique(df.date_id)
    n = len(date_id)
    train_size = math.floor(n*frac)
    date_id_sample = np.sort(np.random.choice(np.unique(df_train.date_id), size=train_size))
    df_frac_train = df[df.date_id.isin(date_id_sample)]
    df_frac_test = df[~df.date_id.isin(date_id_sample)]
    return df_frac_train, df_frac_test

# %%
# Training

models = []
prepros = []
n_model = 5
for i in tqdm(range(n_model)):
    testing_model = deepcopy(model)
    prepro_testing = deepcopy(prepro)
    
    df_frac_train, df_frac_valid = random_split_date(df_train, frac=0.9)

    df_fold_train = df_frac_train
    df_fold_train_target = df_frac_train['target']    
    df_fold_valid = df_frac_valid
    df_fold_valid_target = df_frac_valid['target']

    # Features generation
    df_fold_train = prepro_testing.fit_transform(df_fold_train)
    df_fold_valid = prepro_testing.transform(df_fold_valid)


    testing_model.fit(
                df_fold_train,
                df_fold_train_target,
                eval_set=[(df_fold_valid, df_fold_valid_target)],
                callbacks=[
                    lgb.callback.early_stopping(stopping_rounds=100),
                    lgb.callback.log_evaluation(period=100),
                ],
            )
    gc.collect()

    prepros.append(prepro_testing)
    models.append(testing_model)

joblib.dump((models, prepros), model_filename_test)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=31)
#            2	LOAD_FAST(arg=0, lineno=33)
#            4	LOAD_ATTR(arg=0, lineno=33)
#            6	LOAD_CONST(arg=1, lineno=33)
#            8	BINARY_SUBSCR(arg=None, lineno=33)
#           10	STORE_FAST(arg=2, lineno=33)
#           12	LOAD_GLOBAL(arg=1, lineno=34)
#           14	LOAD_FAST(arg=1, lineno=34)
#           16	CALL_FUNCTION(arg=1, lineno=34)
#           18	STORE_FAST(arg=3, lineno=34)
#           20	LOAD_GLOBAL(arg=2, lineno=35)
#           22	LOAD_METHOD(arg=3, lineno=35)
#           24	LOAD_FAST(arg=2, lineno=35)
#           26	LOAD_FAST(arg=3, lineno=35)
#           28	BUILD_TUPLE(arg=2, lineno=35)
#           30	CALL_METHOD(arg=1, lineno=35)
#           32	STORE_FAST(arg=4, lineno=35)
#           34	LOAD_GLOBAL(arg=4, lineno=36)
#           36	LOAD_FAST(arg=3, lineno=36)
#           38	CALL_FUNCTION(arg=1, lineno=36)
#           40	GET_ITER(arg=None, lineno=36)
# >         42	FOR_ITER(arg=98, lineno=36)
#           44	STORE_FAST(arg=5, lineno=36)
#           46	LOAD_FAST(arg=1, lineno=37)
#           48	LOAD_FAST(arg=5, lineno=37)
#           50	BINARY_SUBSCR(arg=None, lineno=37)
#           52	UNPACK_SEQUENCE(arg=3, lineno=37)
#           54	STORE_FAST(arg=6, lineno=37)
#           56	STORE_FAST(arg=7, lineno=37)
#           58	STORE_FAST(arg=8, lineno=37)
#           60	LOAD_GLOBAL(arg=5, lineno=38)
#           62	LOAD_FAST(arg=2, lineno=38)
#           64	CALL_FUNCTION(arg=1, lineno=38)
#           66	GET_ITER(arg=None, lineno=38)
# >         68	FOR_ITER(arg=84, lineno=38)
#           70	STORE_FAST(arg=9, lineno=38)
#           72	LOAD_GLOBAL(arg=6, lineno=39)
#           74	LOAD_FAST(arg=0, lineno=39)
#           76	LOAD_FAST(arg=9, lineno=39)
#           78	LOAD_FAST(arg=6, lineno=39)
#           80	BUILD_TUPLE(arg=2, lineno=39)
#           82	BINARY_SUBSCR(arg=None, lineno=39)
#           84	LOAD_FAST(arg=0, lineno=39)
#           86	LOAD_FAST(arg=9, lineno=39)
#           88	LOAD_FAST(arg=7, lineno=39)
#           90	BUILD_TUPLE(arg=2, lineno=39)
#           92	BINARY_SUBSCR(arg=None, lineno=39)
#           94	LOAD_FAST(arg=0, lineno=39)
#           96	LOAD_FAST(arg=9, lineno=39)
#           98	LOAD_FAST(arg=8, lineno=39)
#          100	BUILD_TUPLE(arg=2, lineno=39)
#          102	BINARY_SUBSCR(arg=None, lineno=39)
#          104	CALL_FUNCTION(arg=3, lineno=39)
#          106	STORE_FAST(arg=10, lineno=39)
#          108	LOAD_GLOBAL(arg=7, lineno=40)
#          110	LOAD_FAST(arg=0, lineno=40)
#          112	LOAD_FAST(arg=9, lineno=40)
#          114	LOAD_FAST(arg=6, lineno=40)
#          116	BUILD_TUPLE(arg=2, lineno=40)
#          118	BINARY_SUBSCR(arg=None, lineno=40)
#          120	LOAD_FAST(arg=0, lineno=40)
#          122	LOAD_FAST(arg=9, lineno=40)
#          124	LOAD_FAST(arg=7, lineno=40)
#          126	BUILD_TUPLE(arg=2, lineno=40)
#          128	BINARY_SUBSCR(arg=None, lineno=40)
#          130	LOAD_FAST(arg=0, lineno=40)
#          132	LOAD_FAST(arg=9, lineno=40)
#          134	LOAD_FAST(arg=8, lineno=40)
#          136	BUILD_TUPLE(arg=2, lineno=40)
#          138	BINARY_SUBSCR(arg=None, lineno=40)
#          140	CALL_FUNCTION(arg=3, lineno=40)
#          142	STORE_FAST(arg=11, lineno=40)
#          144	LOAD_FAST(arg=0, lineno=41)
#          146	LOAD_FAST(arg=9, lineno=41)
#          148	LOAD_FAST(arg=6, lineno=41)
#          150	BUILD_TUPLE(arg=2, lineno=41)
#          152	BINARY_SUBSCR(arg=None, lineno=41)
#          154	LOAD_FAST(arg=0, lineno=41)
#          156	LOAD_FAST(arg=9, lineno=41)
#          158	LOAD_FAST(arg=7, lineno=41)
#          160	BUILD_TUPLE(arg=2, lineno=41)
#          162	BINARY_SUBSCR(arg=None, lineno=41)
#          164	BINARY_ADD(arg=None, lineno=41)
#          166	LOAD_FAST(arg=0, lineno=41)
#          168	LOAD_FAST(arg=9, lineno=41)
#          170	LOAD_FAST(arg=8, lineno=41)
#          172	BUILD_TUPLE(arg=2, lineno=41)
#          174	BINARY_SUBSCR(arg=None, lineno=41)
#          176	BINARY_ADD(arg=None, lineno=41)
#          178	LOAD_FAST(arg=11, lineno=41)
#          180	BINARY_SUBTRACT(arg=None, lineno=41)
#          182	LOAD_FAST(arg=10, lineno=41)
#          184	BINARY_SUBTRACT(arg=None, lineno=41)
#          186	STORE_FAST(arg=12, lineno=41)
#          188	LOAD_FAST(arg=12, lineno=43)
#          190	LOAD_FAST(arg=11, lineno=43)
#          192	COMPARE_OP(arg=2, lineno=43)
#          194	POP_JUMP_IF_FALSE(arg=107, lineno=43)
#          196	LOAD_GLOBAL(arg=2, lineno=44)
#          198	LOAD_ATTR(arg=8, lineno=44)
#          200	LOAD_FAST(arg=4, lineno=44)
#          202	LOAD_FAST(arg=9, lineno=44)
#          204	LOAD_FAST(arg=5, lineno=44)
#          206	BUILD_TUPLE(arg=2, lineno=44)
#          208	STORE_SUBSCR(arg=None, lineno=44)
#          210	JUMP_ABSOLUTE(arg=35, lineno=44)
# >        212	LOAD_FAST(arg=10, lineno=46)
#          214	LOAD_FAST(arg=12, lineno=46)
#          216	BINARY_SUBTRACT(arg=None, lineno=46)
#          218	LOAD_FAST(arg=12, lineno=46)
#          220	LOAD_FAST(arg=11, lineno=46)
#          222	BINARY_SUBTRACT(arg=None, lineno=46)
#          224	BINARY_TRUE_DIVIDE(arg=None, lineno=46)
#          226	LOAD_FAST(arg=4, lineno=46)
#          228	LOAD_FAST(arg=9, lineno=46)
#          230	LOAD_FAST(arg=5, lineno=46)
#          232	BUILD_TUPLE(arg=2, lineno=46)
#          234	STORE_SUBSCR(arg=None, lineno=46)
#          236	JUMP_ABSOLUTE(arg=35, lineno=46)
# >        238	JUMP_ABSOLUTE(arg=22, lineno=38)
# >        240	LOAD_FAST(arg=4, lineno=48)
#          242	RETURN_VALUE(arg=None, lineno=48)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=0 nstack_initial=0)
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=31)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_FAST(arg=0, lineno=33)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_ATTR(arg=0, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$df_values2.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_CONST(arg=1, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$4load_attr.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=BINARY_SUBSCR(arg=None, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$4load_attr.1', '$const6.2']
# DEBUG:numba.core.byteflow:dispatch pc=10, inst=STORE_FAST(arg=2, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.3']
# DEBUG:numba.core.byteflow:dispatch pc=12, inst=LOAD_GLOBAL(arg=1, lineno=34)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=14, inst=LOAD_FAST(arg=1, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$12load_global.4']
# DEBUG:numba.core.byteflow:dispatch pc=16, inst=CALL_FUNCTION(arg=1, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$12load_global.4', '$comb_indices14.5']
# DEBUG:numba.core.byteflow:dispatch pc=18, inst=STORE_FAST(arg=3, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$16call_function.6']
# DEBUG:numba.core.byteflow:dispatch pc=20, inst=LOAD_GLOBAL(arg=2, lineno=35)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=22, inst=LOAD_METHOD(arg=3, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$20load_global.7']
# DEBUG:numba.core.byteflow:dispatch pc=24, inst=LOAD_FAST(arg=2, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$22load_method.8']
# DEBUG:numba.core.byteflow:dispatch pc=26, inst=LOAD_FAST(arg=3, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$22load_method.8', '$num_rows24.9']
# DEBUG:numba.core.byteflow:dispatch pc=28, inst=BUILD_TUPLE(arg=2, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$22load_method.8', '$num_rows24.9', '$num_combinations26.10']
# DEBUG:numba.core.byteflow:dispatch pc=30, inst=CALL_METHOD(arg=1, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$22load_method.8', '$28build_tuple.11']
# DEBUG:numba.core.byteflow:dispatch pc=32, inst=STORE_FAST(arg=4, lineno=35)
# DEBUG:numba.core.byteflow:stack ['$30call_method.12']
# DEBUG:numba.core.byteflow:dispatch pc=34, inst=LOAD_GLOBAL(arg=4, lineno=36)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=36, inst=LOAD_FAST(arg=3, lineno=36)
# DEBUG:numba.core.byteflow:stack ['$34load_global.13']
# DEBUG:numba.core.byteflow:dispatch pc=38, inst=CALL_FUNCTION(arg=1, lineno=36)
# DEBUG:numba.core.byteflow:stack ['$34load_global.13', '$num_combinations36.14']
# DEBUG:numba.core.byteflow:dispatch pc=40, inst=GET_ITER(arg=None, lineno=36)
# DEBUG:numba.core.byteflow:stack ['$38call_function.15']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=42, stack=('$40get_iter.16',), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=42 nstack_initial=1)])
# DEBUG:numba.core.byteflow:stack: ['$phi42.0']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=42 nstack_initial=1)
# DEBUG:numba.core.byteflow:dispatch pc=42, inst=FOR_ITER(arg=98, lineno=36)
# DEBUG:numba.core.byteflow:stack ['$phi42.0']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=240, stack=(), blockstack=(), npush=0), Edge(pc=44, stack=('$phi42.0', '$42for_iter.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=240 nstack_initial=0), State(pc_initial=44 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=240 nstack_initial=0)
# DEBUG:numba.core.byteflow:dispatch pc=240, inst=LOAD_FAST(arg=4, lineno=48)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=242, inst=RETURN_VALUE(arg=None, lineno=48)
# DEBUG:numba.core.byteflow:stack ['$imbalance_features240.0']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=44 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi44.0', '$phi44.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=44 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=44, inst=STORE_FAST(arg=5, lineno=36)
# DEBUG:numba.core.byteflow:stack ['$phi44.0', '$phi44.1']
# DEBUG:numba.core.byteflow:dispatch pc=46, inst=LOAD_FAST(arg=1, lineno=37)
# DEBUG:numba.core.byteflow:stack ['$phi44.0']
# DEBUG:numba.core.byteflow:dispatch pc=48, inst=LOAD_FAST(arg=5, lineno=37)
# DEBUG:numba.core.byteflow:stack ['$phi44.0', '$comb_indices46.2']
# DEBUG:numba.core.byteflow:dispatch pc=50, inst=BINARY_SUBSCR(arg=None, lineno=37)
# DEBUG:numba.core.byteflow:stack ['$phi44.0', '$comb_indices46.2', '$i48.3']
# DEBUG:numba.core.byteflow:dispatch pc=52, inst=UNPACK_SEQUENCE(arg=3, lineno=37)
# DEBUG:numba.core.byteflow:stack ['$phi44.0', '$50binary_subscr.4']
# DEBUG:numba.core.byteflow:dispatch pc=54, inst=STORE_FAST(arg=6, lineno=37)
# DEBUG:numba.core.byteflow:stack ['$phi44.0', '$52unpack_sequence.7', '$52unpack_sequence.6', '$52unpack_sequence.5']
# DEBUG:numba.core.byteflow:dispatch pc=56, inst=STORE_FAST(arg=7, lineno=37)
# DEBUG:numba.core.byteflow:stack ['$phi44.0', '$52unpack_sequence.7', '$52unpack_sequence.6']
# DEBUG:numba.core.byteflow:dispatch pc=58, inst=STORE_FAST(arg=8, lineno=37)
# DEBUG:numba.core.byteflow:stack ['$phi44.0', '$52unpack_sequence.7']
# DEBUG:numba.core.byteflow:dispatch pc=60, inst=LOAD_GLOBAL(arg=5, lineno=38)
# DEBUG:numba.core.byteflow:stack ['$phi44.0']
# DEBUG:numba.core.byteflow:dispatch pc=62, inst=LOAD_FAST(arg=2, lineno=38)
# DEBUG:numba.core.byteflow:stack ['$phi44.0', '$60load_global.9']
# DEBUG:numba.core.byteflow:dispatch pc=64, inst=CALL_FUNCTION(arg=1, lineno=38)
# DEBUG:numba.core.byteflow:stack ['$phi44.0', '$60load_global.9', '$num_rows62.10']
# DEBUG:numba.core.byteflow:dispatch pc=66, inst=GET_ITER(arg=None, lineno=38)
# DEBUG:numba.core.byteflow:stack ['$phi44.0', '$64call_function.11']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=68, stack=('$phi44.0', '$66get_iter.12'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=68 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi68.0', '$phi68.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=68 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=68, inst=FOR_ITER(arg=84, lineno=38)
# DEBUG:numba.core.byteflow:stack ['$phi68.0', '$phi68.1']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=238, stack=('$phi68.0',), blockstack=(), npush=0), Edge(pc=70, stack=('$phi68.0', '$phi68.1', '$68for_iter.3'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=238 nstack_initial=1), State(pc_initial=70 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi238.0']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=238 nstack_initial=1)
# DEBUG:numba.core.byteflow:dispatch pc=238, inst=JUMP_ABSOLUTE(arg=22, lineno=38)
# DEBUG:numba.core.byteflow:stack ['$phi238.0']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=42, stack=('$phi238.0',), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=70 nstack_initial=3), State(pc_initial=42 nstack_initial=1)])
# DEBUG:numba.core.byteflow:stack: ['$phi70.0', '$phi70.1', '$phi70.2']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=70 nstack_initial=3)
# DEBUG:numba.core.byteflow:dispatch pc=70, inst=STORE_FAST(arg=9, lineno=38)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$phi70.2']
# DEBUG:numba.core.byteflow:dispatch pc=72, inst=LOAD_GLOBAL(arg=6, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1']
# DEBUG:numba.core.byteflow:dispatch pc=74, inst=LOAD_FAST(arg=0, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$72load_global.3']
# DEBUG:numba.core.byteflow:dispatch pc=76, inst=LOAD_FAST(arg=9, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$72load_global.3', '$df_values74.4']
# DEBUG:numba.core.byteflow:dispatch pc=78, inst=LOAD_FAST(arg=6, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$72load_global.3', '$df_values74.4', '$j76.5']
# DEBUG:numba.core.byteflow:dispatch pc=80, inst=BUILD_TUPLE(arg=2, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$72load_global.3', '$df_values74.4', '$j76.5', '$a78.6']
# DEBUG:numba.core.byteflow:dispatch pc=82, inst=BINARY_SUBSCR(arg=None, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$72load_global.3', '$df_values74.4', '$80build_tuple.7']
# DEBUG:numba.core.byteflow:dispatch pc=84, inst=LOAD_FAST(arg=0, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$72load_global.3', '$82binary_subscr.8']
# DEBUG:numba.core.byteflow:dispatch pc=86, inst=LOAD_FAST(arg=9, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$72load_global.3', '$82binary_subscr.8', '$df_values84.9']
# DEBUG:numba.core.byteflow:dispatch pc=88, inst=LOAD_FAST(arg=7, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$72load_global.3', '$82binary_subscr.8', '$df_values84.9', '$j86.10']
# DEBUG:numba.core.byteflow:dispatch pc=90, inst=BUILD_TUPLE(arg=2, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$72load_global.3', '$82binary_subscr.8', '$df_values84.9', '$j86.10', '$b88.11']
# DEBUG:numba.core.byteflow:dispatch pc=92, inst=BINARY_SUBSCR(arg=None, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$72load_global.3', '$82binary_subscr.8', '$df_values84.9', '$90build_tuple.12']
# DEBUG:numba.core.byteflow:dispatch pc=94, inst=LOAD_FAST(arg=0, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$72load_global.3', '$82binary_subscr.8', '$92binary_subscr.13']
# DEBUG:numba.core.byteflow:dispatch pc=96, inst=LOAD_FAST(arg=9, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$72load_global.3', '$82binary_subscr.8', '$92binary_subscr.13', '$df_values94.14']
# DEBUG:numba.core.byteflow:dispatch pc=98, inst=LOAD_FAST(arg=8, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$72load_global.3', '$82binary_subscr.8', '$92binary_subscr.13', '$df_values94.14', '$j96.15']
# DEBUG:numba.core.byteflow:dispatch pc=100, inst=BUILD_TUPLE(arg=2, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$72load_global.3', '$82binary_subscr.8', '$92binary_subscr.13', '$df_values94.14', '$j96.15', '$c98.16']
# DEBUG:numba.core.byteflow:dispatch pc=102, inst=BINARY_SUBSCR(arg=None, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$72load_global.3', '$82binary_subscr.8', '$92binary_subscr.13', '$df_values94.14', '$100build_tuple.17']
# DEBUG:numba.core.byteflow:dispatch pc=104, inst=CALL_FUNCTION(arg=3, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$72load_global.3', '$82binary_subscr.8', '$92binary_subscr.13', '$102binary_subscr.18']
# DEBUG:numba.core.byteflow:dispatch pc=106, inst=STORE_FAST(arg=10, lineno=39)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$104call_function.19']
# DEBUG:numba.core.byteflow:dispatch pc=108, inst=LOAD_GLOBAL(arg=7, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1']
# DEBUG:numba.core.byteflow:dispatch pc=110, inst=LOAD_FAST(arg=0, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$108load_global.20']
# DEBUG:numba.core.byteflow:dispatch pc=112, inst=LOAD_FAST(arg=9, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$108load_global.20', '$df_values110.21']
# DEBUG:numba.core.byteflow:dispatch pc=114, inst=LOAD_FAST(arg=6, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$108load_global.20', '$df_values110.21', '$j112.22']
# DEBUG:numba.core.byteflow:dispatch pc=116, inst=BUILD_TUPLE(arg=2, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$108load_global.20', '$df_values110.21', '$j112.22', '$a114.23']
# DEBUG:numba.core.byteflow:dispatch pc=118, inst=BINARY_SUBSCR(arg=None, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$108load_global.20', '$df_values110.21', '$116build_tuple.24']
# DEBUG:numba.core.byteflow:dispatch pc=120, inst=LOAD_FAST(arg=0, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$108load_global.20', '$118binary_subscr.25']
# DEBUG:numba.core.byteflow:dispatch pc=122, inst=LOAD_FAST(arg=9, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$108load_global.20', '$118binary_subscr.25', '$df_values120.26']
# DEBUG:numba.core.byteflow:dispatch pc=124, inst=LOAD_FAST(arg=7, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$108load_global.20', '$118binary_subscr.25', '$df_values120.26', '$j122.27']
# DEBUG:numba.core.byteflow:dispatch pc=126, inst=BUILD_TUPLE(arg=2, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$108load_global.20', '$118binary_subscr.25', '$df_values120.26', '$j122.27', '$b124.28']
# DEBUG:numba.core.byteflow:dispatch pc=128, inst=BINARY_SUBSCR(arg=None, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$108load_global.20', '$118binary_subscr.25', '$df_values120.26', '$126build_tuple.29']
# DEBUG:numba.core.byteflow:dispatch pc=130, inst=LOAD_FAST(arg=0, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$108load_global.20', '$118binary_subscr.25', '$128binary_subscr.30']
# DEBUG:numba.core.byteflow:dispatch pc=132, inst=LOAD_FAST(arg=9, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$108load_global.20', '$118binary_subscr.25', '$128binary_subscr.30', '$df_values130.31']
# DEBUG:numba.core.byteflow:dispatch pc=134, inst=LOAD_FAST(arg=8, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$108load_global.20', '$118binary_subscr.25', '$128binary_subscr.30', '$df_values130.31', '$j132.32']
# DEBUG:numba.core.byteflow:dispatch pc=136, inst=BUILD_TUPLE(arg=2, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$108load_global.20', '$118binary_subscr.25', '$128binary_subscr.30', '$df_values130.31', '$j132.32', '$c134.33']
# DEBUG:numba.core.byteflow:dispatch pc=138, inst=BINARY_SUBSCR(arg=None, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$108load_global.20', '$118binary_subscr.25', '$128binary_subscr.30', '$df_values130.31', '$136build_tuple.34']
# DEBUG:numba.core.byteflow:dispatch pc=140, inst=CALL_FUNCTION(arg=3, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$108load_global.20', '$118binary_subscr.25', '$128binary_subscr.30', '$138binary_subscr.35']
# DEBUG:numba.core.byteflow:dispatch pc=142, inst=STORE_FAST(arg=11, lineno=40)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$140call_function.36']
# DEBUG:numba.core.byteflow:dispatch pc=144, inst=LOAD_FAST(arg=0, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1']
# DEBUG:numba.core.byteflow:dispatch pc=146, inst=LOAD_FAST(arg=9, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$df_values144.37']
# DEBUG:numba.core.byteflow:dispatch pc=148, inst=LOAD_FAST(arg=6, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$df_values144.37', '$j146.38']
# DEBUG:numba.core.byteflow:dispatch pc=150, inst=BUILD_TUPLE(arg=2, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$df_values144.37', '$j146.38', '$a148.39']
# DEBUG:numba.core.byteflow:dispatch pc=152, inst=BINARY_SUBSCR(arg=None, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$df_values144.37', '$150build_tuple.40']
# DEBUG:numba.core.byteflow:dispatch pc=154, inst=LOAD_FAST(arg=0, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$152binary_subscr.41']
# DEBUG:numba.core.byteflow:dispatch pc=156, inst=LOAD_FAST(arg=9, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$152binary_subscr.41', '$df_values154.42']
# DEBUG:numba.core.byteflow:dispatch pc=158, inst=LOAD_FAST(arg=7, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$152binary_subscr.41', '$df_values154.42', '$j156.43']
# DEBUG:numba.core.byteflow:dispatch pc=160, inst=BUILD_TUPLE(arg=2, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$152binary_subscr.41', '$df_values154.42', '$j156.43', '$b158.44']
# DEBUG:numba.core.byteflow:dispatch pc=162, inst=BINARY_SUBSCR(arg=None, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$152binary_subscr.41', '$df_values154.42', '$160build_tuple.45']
# DEBUG:numba.core.byteflow:dispatch pc=164, inst=BINARY_ADD(arg=None, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$152binary_subscr.41', '$162binary_subscr.46']
# DEBUG:numba.core.byteflow:dispatch pc=166, inst=LOAD_FAST(arg=0, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$164binary_add.47']
# DEBUG:numba.core.byteflow:dispatch pc=168, inst=LOAD_FAST(arg=9, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$164binary_add.47', '$df_values166.48']
# DEBUG:numba.core.byteflow:dispatch pc=170, inst=LOAD_FAST(arg=8, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$164binary_add.47', '$df_values166.48', '$j168.49']
# DEBUG:numba.core.byteflow:dispatch pc=172, inst=BUILD_TUPLE(arg=2, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$164binary_add.47', '$df_values166.48', '$j168.49', '$c170.50']
# DEBUG:numba.core.byteflow:dispatch pc=174, inst=BINARY_SUBSCR(arg=None, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$164binary_add.47', '$df_values166.48', '$172build_tuple.51']
# DEBUG:numba.core.byteflow:dispatch pc=176, inst=BINARY_ADD(arg=None, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$164binary_add.47', '$174binary_subscr.52']
# DEBUG:numba.core.byteflow:dispatch pc=178, inst=LOAD_FAST(arg=11, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$176binary_add.53']
# DEBUG:numba.core.byteflow:dispatch pc=180, inst=BINARY_SUBTRACT(arg=None, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$176binary_add.53', '$min_val178.54']
# DEBUG:numba.core.byteflow:dispatch pc=182, inst=LOAD_FAST(arg=10, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$180binary_subtract.55']
# DEBUG:numba.core.byteflow:dispatch pc=184, inst=BINARY_SUBTRACT(arg=None, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$180binary_subtract.55', '$max_val182.56']
# DEBUG:numba.core.byteflow:dispatch pc=186, inst=STORE_FAST(arg=12, lineno=41)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$184binary_subtract.57']
# DEBUG:numba.core.byteflow:dispatch pc=188, inst=LOAD_FAST(arg=12, lineno=43)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1']
# DEBUG:numba.core.byteflow:dispatch pc=190, inst=LOAD_FAST(arg=11, lineno=43)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$mid_val188.58']
# DEBUG:numba.core.byteflow:dispatch pc=192, inst=COMPARE_OP(arg=2, lineno=43)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$mid_val188.58', '$min_val190.59']
# DEBUG:numba.core.byteflow:dispatch pc=194, inst=POP_JUMP_IF_FALSE(arg=107, lineno=43)
# DEBUG:numba.core.byteflow:stack ['$phi70.0', '$phi70.1', '$192compare_op.60']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=196, stack=('$phi70.0', '$phi70.1'), blockstack=(), npush=0), Edge(pc=212, stack=('$phi70.0', '$phi70.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=42 nstack_initial=1), State(pc_initial=196 nstack_initial=2), State(pc_initial=212 nstack_initial=2)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=196 nstack_initial=2), State(pc_initial=212 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi196.0', '$phi196.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=196 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=196, inst=LOAD_GLOBAL(arg=2, lineno=44)
# DEBUG:numba.core.byteflow:stack ['$phi196.0', '$phi196.1']
# DEBUG:numba.core.byteflow:dispatch pc=198, inst=LOAD_ATTR(arg=8, lineno=44)
# DEBUG:numba.core.byteflow:stack ['$phi196.0', '$phi196.1', '$196load_global.2']
# DEBUG:numba.core.byteflow:dispatch pc=200, inst=LOAD_FAST(arg=4, lineno=44)
# DEBUG:numba.core.byteflow:stack ['$phi196.0', '$phi196.1', '$198load_attr.3']
# DEBUG:numba.core.byteflow:dispatch pc=202, inst=LOAD_FAST(arg=9, lineno=44)
# DEBUG:numba.core.byteflow:stack ['$phi196.0', '$phi196.1', '$198load_attr.3', '$imbalance_features200.4']
# DEBUG:numba.core.byteflow:dispatch pc=204, inst=LOAD_FAST(arg=5, lineno=44)
# DEBUG:numba.core.byteflow:stack ['$phi196.0', '$phi196.1', '$198load_attr.3', '$imbalance_features200.4', '$j202.5']
# DEBUG:numba.core.byteflow:dispatch pc=206, inst=BUILD_TUPLE(arg=2, lineno=44)
# DEBUG:numba.core.byteflow:stack ['$phi196.0', '$phi196.1', '$198load_attr.3', '$imbalance_features200.4', '$j202.5', '$i204.6']
# DEBUG:numba.core.byteflow:dispatch pc=208, inst=STORE_SUBSCR(arg=None, lineno=44)
# DEBUG:numba.core.byteflow:stack ['$phi196.0', '$phi196.1', '$198load_attr.3', '$imbalance_features200.4', '$206build_tuple.7']
# DEBUG:numba.core.byteflow:dispatch pc=210, inst=JUMP_ABSOLUTE(arg=35, lineno=44)
# DEBUG:numba.core.byteflow:stack ['$phi196.0', '$phi196.1']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=68, stack=('$phi196.0', '$phi196.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=212 nstack_initial=2), State(pc_initial=68 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi212.0', '$phi212.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=212 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=212, inst=LOAD_FAST(arg=10, lineno=46)
# DEBUG:numba.core.byteflow:stack ['$phi212.0', '$phi212.1']
# DEBUG:numba.core.byteflow:dispatch pc=214, inst=LOAD_FAST(arg=12, lineno=46)
# DEBUG:numba.core.byteflow:stack ['$phi212.0', '$phi212.1', '$max_val212.2']
# DEBUG:numba.core.byteflow:dispatch pc=216, inst=BINARY_SUBTRACT(arg=None, lineno=46)
# DEBUG:numba.core.byteflow:stack ['$phi212.0', '$phi212.1', '$max_val212.2', '$mid_val214.3']
# DEBUG:numba.core.byteflow:dispatch pc=218, inst=LOAD_FAST(arg=12, lineno=46)
# DEBUG:numba.core.byteflow:stack ['$phi212.0', '$phi212.1', '$216binary_subtract.4']
# DEBUG:numba.core.byteflow:dispatch pc=220, inst=LOAD_FAST(arg=11, lineno=46)
# DEBUG:numba.core.byteflow:stack ['$phi212.0', '$phi212.1', '$216binary_subtract.4', '$mid_val218.5']
# DEBUG:numba.core.byteflow:dispatch pc=222, inst=BINARY_SUBTRACT(arg=None, lineno=46)
# DEBUG:numba.core.byteflow:stack ['$phi212.0', '$phi212.1', '$216binary_subtract.4', '$mid_val218.5', '$min_val220.6']
# DEBUG:numba.core.byteflow:dispatch pc=224, inst=BINARY_TRUE_DIVIDE(arg=None, lineno=46)
# DEBUG:numba.core.byteflow:stack ['$phi212.0', '$phi212.1', '$216binary_subtract.4', '$222binary_subtract.7']
# DEBUG:numba.core.byteflow:dispatch pc=226, inst=LOAD_FAST(arg=4, lineno=46)
# DEBUG:numba.core.byteflow:stack ['$phi212.0', '$phi212.1', '$224binary_true_divide.8']
# DEBUG:numba.core.byteflow:dispatch pc=228, inst=LOAD_FAST(arg=9, lineno=46)
# DEBUG:numba.core.byteflow:stack ['$phi212.0', '$phi212.1', '$224binary_true_divide.8', '$imbalance_features226.9']
# DEBUG:numba.core.byteflow:dispatch pc=230, inst=LOAD_FAST(arg=5, lineno=46)
# DEBUG:numba.core.byteflow:stack ['$phi212.0', '$phi212.1', '$224binary_true_divide.8', '$imbalance_features226.9', '$j228.10']
# DEBUG:numba.core.byteflow:dispatch pc=232, inst=BUILD_TUPLE(arg=2, lineno=46)
# DEBUG:numba.core.byteflow:stack ['$phi212.0', '$phi212.1', '$224binary_true_divide.8', '$imbalance_features226.9', '$j228.10', '$i230.11']
# DEBUG:numba.core.byteflow:dispatch pc=234, inst=STORE_SUBSCR(arg=None, lineno=46)
# DEBUG:numba.core.byteflow:stack ['$phi212.0', '$phi212.1', '$224binary_true_divide.8', '$imbalance_features226.9', '$232build_tuple.12']
# DEBUG:numba.core.byteflow:dispatch pc=236, inst=JUMP_ABSOLUTE(arg=35, lineno=46)
# DEBUG:numba.core.byteflow:stack ['$phi212.0', '$phi212.1']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=68, stack=('$phi212.0', '$phi212.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=68 nstack_initial=2), State(pc_initial=68 nstack_initial=2)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=68 nstack_initial=2)])
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>,
#             {State(pc_initial=0 nstack_initial=0): set(),
#              State(pc_initial=42 nstack_initial=1): {'$phi42.0'},
#              State(pc_initial=44 nstack_initial=2): {'$phi44.1'},
#              State(pc_initial=68 nstack_initial=2): {'$phi68.1'},
#              State(pc_initial=70 nstack_initial=3): {'$phi70.2'},
#              State(pc_initial=196 nstack_initial=2): set(),
#              State(pc_initial=212 nstack_initial=2): set(),
#              State(pc_initial=238 nstack_initial=1): set(),
#              State(pc_initial=240 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {'$phi42.0': State(pc_initial=0 nstack_initial=0),
#  '$phi44.1': State(pc_initial=42 nstack_initial=1),
#  '$phi68.1': State(pc_initial=44 nstack_initial=2),
#  '$phi70.2': State(pc_initial=68 nstack_initial=2)}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>,
#             {'$phi196.0': {('$phi70.0', State(pc_initial=70 nstack_initial=3))},
#              '$phi196.1': {('$phi70.1', State(pc_initial=70 nstack_initial=3))},
#              '$phi212.0': {('$phi70.0', State(pc_initial=70 nstack_initial=3))},
#              '$phi212.1': {('$phi70.1', State(pc_initial=70 nstack_initial=3))},
#              '$phi238.0': {('$phi68.0', State(pc_initial=68 nstack_initial=2))},
#              '$phi42.0': {('$40get_iter.16',
#                            State(pc_initial=0 nstack_initial=0)),
#                           ('$phi238.0',
#                            State(pc_initial=238 nstack_initial=1))},
#              '$phi44.0': {('$phi42.0', State(pc_initial=42 nstack_initial=1))},
#              '$phi44.1': {('$42for_iter.2',
#                            State(pc_initial=42 nstack_initial=1))},
#              '$phi68.0': {('$phi196.0', State(pc_initial=196 nstack_initial=2)),
#                           ('$phi212.0', State(pc_initial=212 nstack_initial=2)),
#                           ('$phi44.0', State(pc_initial=44 nstack_initial=2))},
#              '$phi68.1': {('$66get_iter.12',
#                            State(pc_initial=44 nstack_initial=2)),
#                           ('$phi196.1', State(pc_initial=196 nstack_initial=2)),
#                           ('$phi212.1',
#                            State(pc_initial=212 nstack_initial=2))},
#              '$phi70.0': {('$phi68.0', State(pc_initial=68 nstack_initial=2))},
#              '$phi70.1': {('$phi68.1', State(pc_initial=68 nstack_initial=2))},
#              '$phi70.2': {('$68for_iter.3',
#                            State(pc_initial=68 nstack_initial=2))}})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>,
#             {'$phi196.0': {('$phi68.0', State(pc_initial=68 nstack_initial=2))},
#              '$phi196.1': {('$phi68.1', State(pc_initial=68 nstack_initial=2))},
#              '$phi212.0': {('$phi68.0', State(pc_initial=68 nstack_initial=2))},
#              '$phi212.1': {('$phi68.1', State(pc_initial=68 nstack_initial=2))},
#              '$phi238.0': {('$phi196.0',
#                             State(pc_initial=196 nstack_initial=2)),
#                            ('$phi212.0',
#                             State(pc_initial=212 nstack_initial=2)),
#                            ('$phi44.0', State(pc_initial=44 nstack_initial=2))},
#              '$phi42.0': {('$40get_iter.16',
#                            State(pc_initial=0 nstack_initial=0)),
#                           ('$phi196.0', State(pc_initial=196 nstack_initial=2)),
#                           ('$phi212.0', State(pc_initial=212 nstack_initial=2)),
#                           ('$phi44.0', State(pc_initial=44 nstack_initial=2))},
#              '$phi44.0': {('$40get_iter.16',
#                            State(pc_initial=0 nstack_initial=0)),
#                           ('$phi196.0', State(pc_initial=196 nstack_initial=2)),
#                           ('$phi212.0', State(pc_initial=212 nstack_initial=2)),
#                           ('$phi44.0', State(pc_initial=44 nstack_initial=2))},
#              '$phi44.1': {('$42for_iter.2',
#                            State(pc_initial=42 nstack_initial=1))},
#              '$phi68.0': {('$40get_iter.16',
#                            State(pc_initial=0 nstack_initial=0)),
#                           ('$phi68.0', State(pc_initial=68 nstack_initial=2))},
#              '$phi68.1': {('$66get_iter.12',
#                            State(pc_initial=44 nstack_initial=2)),
#                           ('$phi68.1', State(pc_initial=68 nstack_initial=2))},
#              '$phi70.0': {('$40get_iter.16',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi70.1': {('$66get_iter.12',
#                            State(pc_initial=44 nstack_initial=2))},
#              '$phi70.2': {('$68for_iter.3',
#                            State(pc_initial=68 nstack_initial=2))}})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>,
#             {'$phi196.0': {('$40get_iter.16',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi196.1': {('$66get_iter.12',
#                             State(pc_initial=44 nstack_initial=2))},
#              '$phi212.0': {('$40get_iter.16',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi212.1': {('$66get_iter.12',
#                             State(pc_initial=44 nstack_initial=2))},
#              '$phi238.0': {('$40get_iter.16',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi42.0': {('$40get_iter.16',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi44.0': {('$40get_iter.16',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi44.1': {('$42for_iter.2',
#                            State(pc_initial=42 nstack_initial=1))},
#              '$phi68.0': {('$40get_iter.16',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi68.1': {('$66get_iter.12',
#                            State(pc_initial=44 nstack_initial=2))},
#              '$phi70.0': {('$40get_iter.16',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi70.1': {('$66get_iter.12',
#                            State(pc_initial=44 nstack_initial=2))},
#              '$phi70.2': {('$68for_iter.3',
#                            State(pc_initial=68 nstack_initial=2))}})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>,
#             {'$phi196.0': {('$40get_iter.16',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi196.1': {('$66get_iter.12',
#                             State(pc_initial=44 nstack_initial=2))},
#              '$phi212.0': {('$40get_iter.16',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi212.1': {('$66get_iter.12',
#                             State(pc_initial=44 nstack_initial=2))},
#              '$phi238.0': {('$40get_iter.16',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi42.0': {('$40get_iter.16',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi44.0': {('$40get_iter.16',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi44.1': {('$42for_iter.2',
#                            State(pc_initial=42 nstack_initial=1))},
#              '$phi68.0': {('$40get_iter.16',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi68.1': {('$66get_iter.12',
#                            State(pc_initial=44 nstack_initial=2))},
#              '$phi70.0': {('$40get_iter.16',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi70.1': {('$66get_iter.12',
#                            State(pc_initial=44 nstack_initial=2))},
#              '$phi70.2': {('$68for_iter.3',
#                            State(pc_initial=68 nstack_initial=2))}})
# DEBUG:numba.core.byteflow:keep phismap: {'$phi42.0': {('$40get_iter.16', State(pc_initial=0 nstack_initial=0))},
#  '$phi44.1': {('$42for_iter.2', State(pc_initial=42 nstack_initial=1))},
#  '$phi68.1': {('$66get_iter.12', State(pc_initial=44 nstack_initial=2))},
#  '$phi70.2': {('$68for_iter.3', State(pc_initial=68 nstack_initial=2))}}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>,
#             {State(pc_initial=0 nstack_initial=0): {'$phi42.0': '$40get_iter.16'},
#              State(pc_initial=42 nstack_initial=1): {'$phi44.1': '$42for_iter.2'},
#              State(pc_initial=44 nstack_initial=2): {'$phi68.1': '$66get_iter.12'},
#              State(pc_initial=68 nstack_initial=2): {'$phi70.2': '$68for_iter.3'}})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$df_values2.0'}), (4, {'item': '$df_values2.0', 'res': '$4load_attr.1'}), (6, {'res': '$const6.2'}), (8, {'index': '$const6.2', 'target': '$4load_attr.1', 'res': '$8binary_subscr.3'}), (10, {'value': '$8binary_subscr.3'}), (12, {'res': '$12load_global.4'}), (14, {'res': '$comb_indices14.5'}), (16, {'func': '$12load_global.4', 'args': ['$comb_indices14.5'], 'res': '$16call_function.6'}), (18, {'value': '$16call_function.6'}), (20, {'res': '$20load_global.7'}), (22, {'item': '$20load_global.7', 'res': '$22load_method.8'}), (24, {'res': '$num_rows24.9'}), (26, {'res': '$num_combinations26.10'}), (28, {'items': ['$num_rows24.9', '$num_combinations26.10'], 'res': '$28build_tuple.11'}), (30, {'func': '$22load_method.8', 'args': ['$28build_tuple.11'], 'res': '$30call_method.12'}), (32, {'value': '$30call_method.12'}), (34, {'res': '$34load_global.13'}), (36, {'res': '$num_combinations36.14'}), (38, {'func': '$34load_global.13', 'args': ['$num_combinations36.14'], 'res': '$38call_function.15'}), (40, {'value': '$38call_function.15', 'res': '$40get_iter.16'})), outgoing_phis={'$phi42.0': '$40get_iter.16'}, blockstack=(), active_try_block=None, outgoing_edgepushed={42: ('$40get_iter.16',)})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=42 nstack_initial=1):
# AdaptBlockInfo(insts=((42, {'iterator': '$phi42.0', 'pair': '$42for_iter.1', 'indval': '$42for_iter.2', 'pred': '$42for_iter.3'}),), outgoing_phis={'$phi44.1': '$42for_iter.2'}, blockstack=(), active_try_block=None, outgoing_edgepushed={240: (), 44: ('$phi42.0', '$42for_iter.2')})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=44 nstack_initial=2):
# AdaptBlockInfo(insts=((44, {'value': '$phi44.1'}), (46, {'res': '$comb_indices46.2'}), (48, {'res': '$i48.3'}), (50, {'index': '$i48.3', 'target': '$comb_indices46.2', 'res': '$50binary_subscr.4'}), (52, {'iterable': '$50binary_subscr.4', 'stores': ['$52unpack_sequence.5', '$52unpack_sequence.6', '$52unpack_sequence.7'], 'tupleobj': '$52unpack_sequence.8'}), (54, {'value': '$52unpack_sequence.5'}), (56, {'value': '$52unpack_sequence.6'}), (58, {'value': '$52unpack_sequence.7'}), (60, {'res': '$60load_global.9'}), (62, {'res': '$num_rows62.10'}), (64, {'func': '$60load_global.9', 'args': ['$num_rows62.10'], 'res': '$64call_function.11'}), (66, {'value': '$64call_function.11', 'res': '$66get_iter.12'})), outgoing_phis={'$phi68.1': '$66get_iter.12'}, blockstack=(), active_try_block=None, outgoing_edgepushed={68: ('$phi44.0', '$66get_iter.12')})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=68 nstack_initial=2):
# AdaptBlockInfo(insts=((68, {'iterator': '$phi68.1', 'pair': '$68for_iter.2', 'indval': '$68for_iter.3', 'pred': '$68for_iter.4'}),), outgoing_phis={'$phi70.2': '$68for_iter.3'}, blockstack=(), active_try_block=None, outgoing_edgepushed={238: ('$phi68.0',), 70: ('$phi68.0', '$phi68.1', '$68for_iter.3')})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=70 nstack_initial=3):
# AdaptBlockInfo(insts=((70, {'value': '$phi70.2'}), (72, {'res': '$72load_global.3'}), (74, {'res': '$df_values74.4'}), (76, {'res': '$j76.5'}), (78, {'res': '$a78.6'}), (80, {'items': ['$j76.5', '$a78.6'], 'res': '$80build_tuple.7'}), (82, {'index': '$80build_tuple.7', 'target': '$df_values74.4', 'res': '$82binary_subscr.8'}), (84, {'res': '$df_values84.9'}), (86, {'res': '$j86.10'}), (88, {'res': '$b88.11'}), (90, {'items': ['$j86.10', '$b88.11'], 'res': '$90build_tuple.12'}), (92, {'index': '$90build_tuple.12', 'target': '$df_values84.9', 'res': '$92binary_subscr.13'}), (94, {'res': '$df_values94.14'}), (96, {'res': '$j96.15'}), (98, {'res': '$c98.16'}), (100, {'items': ['$j96.15', '$c98.16'], 'res': '$100build_tuple.17'}), (102, {'index': '$100build_tuple.17', 'target': '$df_values94.14', 'res': '$102binary_subscr.18'}), (104, {'func': '$72load_global.3', 'args': ['$82binary_subscr.8', '$92binary_subscr.13', '$102binary_subscr.18'], 'res': '$104call_function.19'}), (106, {'value': '$104call_function.19'}), (108, {'res': '$108load_global.20'}), (110, {'res': '$df_values110.21'}), (112, {'res': '$j112.22'}), (114, {'res': '$a114.23'}), (116, {'items': ['$j112.22', '$a114.23'], 'res': '$116build_tuple.24'}), (118, {'index': '$116build_tuple.24', 'target': '$df_values110.21', 'res': '$118binary_subscr.25'}), (120, {'res': '$df_values120.26'}), (122, {'res': '$j122.27'}), (124, {'res': '$b124.28'}), (126, {'items': ['$j122.27', '$b124.28'], 'res': '$126build_tuple.29'}), (128, {'index': '$126build_tuple.29', 'target': '$df_values120.26', 'res': '$128binary_subscr.30'}), (130, {'res': '$df_values130.31'}), (132, {'res': '$j132.32'}), (134, {'res': '$c134.33'}), (136, {'items': ['$j132.32', '$c134.33'], 'res': '$136build_tuple.34'}), (138, {'index': '$136build_tuple.34', 'target': '$df_values130.31', 'res': '$138binary_subscr.35'}), (140, {'func': '$108load_global.20', 'args': ['$118binary_subscr.25', '$128binary_subscr.30', '$138binary_subscr.35'], 'res': '$140call_function.36'}), (142, {'value': '$140call_function.36'}), (144, {'res': '$df_values144.37'}), (146, {'res': '$j146.38'}), (148, {'res': '$a148.39'}), (150, {'items': ['$j146.38', '$a148.39'], 'res': '$150build_tuple.40'}), (152, {'index': '$150build_tuple.40', 'target': '$df_values144.37', 'res': '$152binary_subscr.41'}), (154, {'res': '$df_values154.42'}), (156, {'res': '$j156.43'}), (158, {'res': '$b158.44'}), (160, {'items': ['$j156.43', '$b158.44'], 'res': '$160build_tuple.45'}), (162, {'index': '$160build_tuple.45', 'target': '$df_values154.42', 'res': '$162binary_subscr.46'}), (164, {'lhs': '$152binary_subscr.41', 'rhs': '$162binary_subscr.46', 'res': '$164binary_add.47'}), (166, {'res': '$df_values166.48'}), (168, {'res': '$j168.49'}), (170, {'res': '$c170.50'}), (172, {'items': ['$j168.49', '$c170.50'], 'res': '$172build_tuple.51'}), (174, {'index': '$172build_tuple.51', 'target': '$df_values166.48', 'res': '$174binary_subscr.52'}), (176, {'lhs': '$164binary_add.47', 'rhs': '$174binary_subscr.52', 'res': '$176binary_add.53'}), (178, {'res': '$min_val178.54'}), (180, {'lhs': '$176binary_add.53', 'rhs': '$min_val178.54', 'res': '$180binary_subtract.55'}), (182, {'res': '$max_val182.56'}), (184, {'lhs': '$180binary_subtract.55', 'rhs': '$max_val182.56', 'res': '$184binary_subtract.57'}), (186, {'value': '$184binary_subtract.57'}), (188, {'res': '$mid_val188.58'}), (190, {'res': '$min_val190.59'}), (192, {'lhs': '$mid_val188.58', 'rhs': '$min_val190.59', 'res': '$192compare_op.60'}), (194, {'pred': '$192compare_op.60'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={196: ('$phi70.0', '$phi70.1'), 212: ('$phi70.0', '$phi70.1')})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=196 nstack_initial=2):
# AdaptBlockInfo(insts=((196, {'res': '$196load_global.2'}), (198, {'item': '$196load_global.2', 'res': '$198load_attr.3'}), (200, {'res': '$imbalance_features200.4'}), (202, {'res': '$j202.5'}), (204, {'res': '$i204.6'}), (206, {'items': ['$j202.5', '$i204.6'], 'res': '$206build_tuple.7'}), (208, {'target': '$imbalance_features200.4', 'index': '$206build_tuple.7', 'value': '$198load_attr.3'}), (210, {})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={68: ('$phi196.0', '$phi196.1')})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=212 nstack_initial=2):
# AdaptBlockInfo(insts=((212, {'res': '$max_val212.2'}), (214, {'res': '$mid_val214.3'}), (216, {'lhs': '$max_val212.2', 'rhs': '$mid_val214.3', 'res': '$216binary_subtract.4'}), (218, {'res': '$mid_val218.5'}), (220, {'res': '$min_val220.6'}), (222, {'lhs': '$mid_val218.5', 'rhs': '$min_val220.6', 'res': '$222binary_subtract.7'}), (224, {'lhs': '$216binary_subtract.4', 'rhs': '$222binary_subtract.7', 'res': '$224binary_true_divide.8'}), (226, {'res': '$imbalance_features226.9'}), (228, {'res': '$j228.10'}), (230, {'res': '$i230.11'}), (232, {'items': ['$j228.10', '$i230.11'], 'res': '$232build_tuple.12'}), (234, {'target': '$imbalance_features226.9', 'index': '$232build_tuple.12', 'value': '$224binary_true_divide.8'}), (236, {})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={68: ('$phi212.0', '$phi212.1')})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=238 nstack_initial=1):
# AdaptBlockInfo(insts=((238, {}),), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={42: ('$phi238.0',)})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=240 nstack_initial=0):
# AdaptBlockInfo(insts=((240, {'res': '$imbalance_features240.0'}), (242, {'retval': '$imbalance_features240.0', 'castval': '$242return_value.1'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     df_values = arg(0, name=df_values)       ['df_values']
#     comb_indices = arg(1, name=comb_indices) ['comb_indices']
#     $4load_attr.1 = getattr(value=df_values, attr=shape) ['$4load_attr.1', 'df_values']
#     $const6.2 = const(int, 0)                ['$const6.2']
#     num_rows = getitem(value=$4load_attr.1, index=$const6.2, fn=<built-in function getitem>) ['$4load_attr.1', '$const6.2', 'num_rows']
#     $12load_global.4 = global(len: <built-in function len>) ['$12load_global.4']
# ...
# DEBUG:numba.core.byteflow:dispatch pc=16, inst=LOAD_GLOBAL(arg=1, lineno=2)
# DEBUG:numba.core.byteflow:stack ['$2load_global.0', '$8binary_subscr.3', '$14binary_subscr.6']
# DEBUG:numba.core.byteflow:dispatch pc=18, inst=LOAD_METHOD(arg=2, lineno=2)
# DEBUG:numba.core.byteflow:stack ['$2load_global.0', '$8binary_subscr.3', '$14binary_subscr.6', '$16load_global.7']
# DEBUG:numba.core.byteflow:dispatch pc=20, inst=LOAD_CONST(arg=2, lineno=2)
# DEBUG:numba.core.byteflow:stack ['$2load_global.0', '$8binary_subscr.3', '$14binary_subscr.6', '$18load_method.8']
# DEBUG:numba.core.byteflow:dispatch pc=22, inst=CALL_METHOD(arg=1, lineno=2)
# DEBUG:numba.core.byteflow:stack ['$2load_global.0', '$8binary_subscr.3', '$14binary_subscr.6', '$18load_method.8', '$const20.9']
# DEBUG:numba.core.byteflow:dispatch pc=24, inst=BINARY_ADD(arg=None, lineno=2)
# DEBUG:numba.core.byteflow:stack ['$2load_global.0', '$8binary_subscr.3', '$14binary_subscr.6', '$22call_method.10']
# DEBUG:numba.core.byteflow:dispatch pc=26, inst=CALL_FUNCTION(arg=2, lineno=2)
# DEBUG:numba.core.byteflow:stack ['$2load_global.0', '$8binary_subscr.3', '$24binary_add.11']
# DEBUG:numba.core.byteflow:dispatch pc=28, inst=GET_ITER(arg=None, lineno=2)
# DEBUG:numba.core.byteflow:stack ['$26call_function.12']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=30, stack=('$28get_iter.13',), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=30 nstack_initial=1)])
# DEBUG:numba.core.byteflow:stack: ['$phi30.0']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=30 nstack_initial=1)
# DEBUG:numba.core.byteflow:dispatch pc=30, inst=FOR_ITER(arg=4, lineno=2)
# DEBUG:numba.core.byteflow:stack ['$phi30.0']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=40, stack=(), blockstack=(), npush=0), Edge(pc=32, stack=('$phi30.0', '$30for_iter.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=40 nstack_initial=0), State(pc_initial=32 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=40 nstack_initial=0)
# DEBUG:numba.core.byteflow:dispatch pc=40, inst=LOAD_CONST(arg=0, lineno=4)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=42, inst=RETURN_VALUE(arg=None, lineno=4)
# DEBUG:numba.core.byteflow:stack ['$const40.0']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=32 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi32.0', '$phi32.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=32 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=32, inst=STORE_FAST(arg=5, lineno=2)
# DEBUG:numba.core.byteflow:stack ['$phi32.0', '$phi32.1']
# DEBUG:numba.core.byteflow:dispatch pc=34, inst=LOAD_CONST(arg=1, lineno=3)
# DEBUG:numba.core.byteflow:stack ['$phi32.0']
# DEBUG:numba.core.byteflow:dispatch pc=36, inst=STORE_FAST(arg=6, lineno=3)
# DEBUG:numba.core.byteflow:stack ['$phi32.0', '$const34.2']
# DEBUG:numba.core.byteflow:dispatch pc=38, inst=JUMP_ABSOLUTE(arg=16, lineno=3)
# DEBUG:numba.core.byteflow:stack ['$phi32.0']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=30, stack=('$phi32.0',), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=30 nstack_initial=1)])
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>,
#             {State(pc_initial=0 nstack_initial=0): set(),
#              State(pc_initial=30 nstack_initial=1): {'$phi30.0'},
#              State(pc_initial=32 nstack_initial=2): {'$phi32.1'},
#              State(pc_initial=40 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {'$phi30.0': State(pc_initial=0 nstack_initial=0),
#  '$phi32.1': State(pc_initial=30 nstack_initial=1)}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>,
#             {'$phi30.0': {('$28get_iter.13',
#                            State(pc_initial=0 nstack_initial=0)),
#                           ('$phi32.0', State(pc_initial=32 nstack_initial=2))},
#              '$phi32.0': {('$phi30.0', State(pc_initial=30 nstack_initial=1))},
#              '$phi32.1': {('$30for_iter.2',
#                            State(pc_initial=30 nstack_initial=1))}})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>,
#             {'$phi30.0': {('$28get_iter.13',
#                            State(pc_initial=0 nstack_initial=0)),
#                           ('$phi30.0', State(pc_initial=30 nstack_initial=1))},
#              '$phi32.0': {('$28get_iter.13',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi32.1': {('$30for_iter.2',
#                            State(pc_initial=30 nstack_initial=1))}})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>,
#             {'$phi30.0': {('$28get_iter.13',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi32.0': {('$28get_iter.13',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi32.1': {('$30for_iter.2',
#                            State(pc_initial=30 nstack_initial=1))}})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>,
#             {'$phi30.0': {('$28get_iter.13',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi32.0': {('$28get_iter.13',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi32.1': {('$30for_iter.2',
#                            State(pc_initial=30 nstack_initial=1))}})
# DEBUG:numba.core.byteflow:keep phismap: {'$phi30.0': {('$28get_iter.13', State(pc_initial=0 nstack_initial=0))},
#  '$phi32.1': {('$30for_iter.2', State(pc_initial=30 nstack_initial=1))}}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>,
#             {State(pc_initial=0 nstack_initial=0): {'$phi30.0': '$28get_iter.13'},
#              State(pc_initial=30 nstack_initial=1): {'$phi32.1': '$30for_iter.2'}})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$2load_global.0'}), (4, {'res': '$sched4.1'}), (6, {'res': '$const6.2'}), (8, {'index': '$const6.2', 'target': '$sched4.1', 'res': '$8binary_subscr.3'}), (10, {'res': '$sched10.4'}), (12, {'res': '$const12.5'}), (14, {'index': '$const12.5', 'target': '$sched10.4', 'res': '$14binary_subscr.6'}), (16, {'res': '$16load_global.7'}), (18, {'item': '$16load_global.7', 'res': '$18load_method.8'}), (20, {'res': '$const20.9'}), (22, {'func': '$18load_method.8', 'args': ['$const20.9'], 'res': '$22call_method.10'}), (24, {'lhs': '$14binary_subscr.6', 'rhs': '$22call_method.10', 'res': '$24binary_add.11'}), (26, {'func': '$2load_global.0', 'args': ['$8binary_subscr.3', '$24binary_add.11'], 'res': '$26call_function.12'}), (28, {'value': '$26call_function.12', 'res': '$28get_iter.13'})), outgoing_phis={'$phi30.0': '$28get_iter.13'}, blockstack=(), active_try_block=None, outgoing_edgepushed={30: ('$28get_iter.13',)})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=30 nstack_initial=1):
# AdaptBlockInfo(insts=((30, {'iterator': '$phi30.0', 'pair': '$30for_iter.1', 'indval': '$30for_iter.2', 'pred': '$30for_iter.3'}),), outgoing_phis={'$phi32.1': '$30for_iter.2'}, blockstack=(), active_try_block=None, outgoing_edgepushed={40: (), 32: ('$phi30.0', '$30for_iter.2')})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=32 nstack_initial=2):
# AdaptBlockInfo(insts=((32, {'value': '$phi32.1'}), (34, {'res': '$const34.2'}), (36, {'value': '$const34.2'}), (38, {})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={30: ('$phi32.0',)})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=40 nstack_initial=0):
# AdaptBlockInfo(insts=((40, {'res': '$const40.0'}), (42, {'retval': '$const40.0', 'castval': '$42return_value.1'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     sched = arg(0, name=sched)               ['sched']
#     comb__indices = arg(1, name=comb__indices) ['comb__indices']
#     df__values = arg(2, name=df__values)     ['df__values']
#     imbalance__features = arg(3, name=imbalance__features) ['imbalance__features']
#     num__rows = arg(4, name=num__rows)       ['num__rows']
#     $2load_global.0 = global(range: <class 'range'>) ['$2load_global.0']
#     $const6.2 = const(int, 0)                ['$const6.2']
#     $8binary_subscr.3 = getitem(value=sched, index=$const6.2, fn=<built-in function getitem>) ['$8binary_subscr.3', '$const6.2', 'sched']
#     $const12.5 = const(int, 1)               ['$const12.5']
#     $14binary_subscr.6 = getitem(value=sched, index=$const12.5, fn=<built-in function getitem>) ['$14binary_subscr.6', '$const12.5', 'sched']
#     $16load_global.7 = global(np: <module 'numpy' from '/Users/eric/code/Kaggle_/.testlgbm/lib/python3.10/site-packages/numpy/__init__.py'>) ['$16load_global.7']
#     $18load_method.8 = getattr(value=$16load_global.7, attr=uint8) ['$16load_global.7', '$18load_method.8']
#     $const20.9 = const(int, 1)               ['$const20.9']
#     $22call_method.10 = call $18load_method.8($const20.9, func=$18load_method.8, args=[Var($const20.9, <string>:2)], kws=(), vararg=None, varkwarg=None, target=None) ['$18load_method.8', '$22call_method.10', '$const20.9']
#     $24binary_add.11 = $14binary_subscr.6 + $22call_method.10 ['$14binary_subscr.6', '$22call_method.10', '$24binary_add.11']
#     $26call_function.12 = call $2load_global.0($8binary_subscr.3, $24binary_add.11, func=$2load_global.0, args=[Var($8binary_subscr.3, <string>:2), Var($24binary_add.11, <string>:2)], kws=(), vararg=None, varkwarg=None, target=None) ['$24binary_add.11', '$26call_function.12', '$2load_global.0', '$8binary_subscr.3']
#     $28get_iter.13 = getiter(value=$26call_function.12) ['$26call_function.12', '$28get_iter.13']
#     $phi30.0 = $28get_iter.13                ['$28get_iter.13', '$phi30.0']
#     jump 30                                  []
# label 30:
#     $30for_iter.1 = iternext(value=$phi30.0) ['$30for_iter.1', '$phi30.0']
#     $30for_iter.2 = pair_first(value=$30for_iter.1) ['$30for_iter.1', '$30for_iter.2']
#     $30for_iter.3 = pair_second(value=$30for_iter.1) ['$30for_iter.1', '$30for_iter.3']
#     $phi32.1 = $30for_iter.2                 ['$30for_iter.2', '$phi32.1']
#     branch $30for_iter.3, 32, 40             ['$30for_iter.3']
# label 32:
#     parfor__index_16 = $phi32.1              ['$phi32.1', 'parfor__index_16']
#     __sentinel__0 = const(int, 0)            ['__sentinel__0']
#     jump 30                                  []
# label 40:
#     $const40.0 = const(NoneType, None)       ['$const40.0']
#     $42return_value.1 = cast(value=$const40.0) ['$42return_value.1', '$const40.0']
#     return $42return_value.1                 ['$42return_value.1']
#   0%|          | 0/5 [00:08<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 18
#      15 df_fold_valid_target = df_frac_valid['target']
#      17 # Features generation
# ---> 18 df_fold_train = prepro_testing.fit_transform(df_fold_train)
#      19 df_fold_valid = prepro_testing.transform(df_fold_valid)
#      22 testing_model.fit(
#      23             df_fold_train,
#      24             df_fold_train_target,
#    (...)
#      29             ],
#      30         )
#
# File ~/code/Kaggle_/Optiver/utils_kgl/processing.py:213, in Preprocessing_null.fit_transform(self, df)
#     211 def fit_transform(self, df):
#     212     self.fit(df)
# --> 213     return self.transform(df)
#
# File ~/code/Kaggle_/Optiver/utils_kgl/processing.py:222, in Preprocessing.transform(self, df)
#     221 def transform(self, df):
# --> 222     df_feats = generate_all_features(df, self.global_stock_id_feats)
#     223     df_feats = reduce_mem_usage(df_feats)
#     224     return df_feats
#
# File ~/code/Kaggle_/Optiver/utils_kgl/processing.py:182, in generate_all_features(df, global_stock_id_feats)
#     179 df = df[cols]
#     181 # Generate imbalance features
# --> 182 df = imbalance_features(df)
#     183 gc.collect()
#     184 df = other_features(df, global_stock_id_feats)
#
# File ~/code/Kaggle_/Optiver/utils_kgl/processing.py:103, in imbalance_features(df)
#     101     for window in [1,3,5,10]:
#     102         df[f"{col}_shift_{window}"] = df.groupby('stock_id')[col].shift(window)
# --> 103         df[f"{col}_ret_{window}"] = df.groupby('stock_id')[col].pct_change(window)
#     105 # Calculate diff features for specific columns
#     106 for col in ['ask_price', 'bid_price', 'ask_size', 'bid_size', 'weighted_wap','price_spread']:
#
# File ~/code/Kaggle_/.testlgbm/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:5325, in GroupBy.pct_change(self, periods, fill_method, limit, freq, axis)
#    5323 else:
#    5324     fill_grp = filled.T.groupby(self.grouper.codes, group_keys=self.group_keys)
# -> 5325 shifted = fill_grp.shift(periods=periods, freq=freq)
#    5326 if self.axis == 1:
#    5327     shifted = shifted.T
#
# File ~/code/Kaggle_/.testlgbm/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:5087, in GroupBy.shift(self, periods, freq, axis, fill_value, suffix)
#    5085 if fill_value is lib.no_default:
#    5086     fill_value = None
# -> 5087 ids, _, ngroups = self.grouper.group_info
#    5088 res_indexer = np.zeros(len(ids), dtype=np.int64)
#    5090 libgroupby.group_shift_indexer(res_indexer, ids, ngroups, period)
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/code/Kaggle_/.testlgbm/lib/python3.10/site-packages/pandas/core/groupby/ops.py:730, in BaseGrouper.group_info(self)
#     728 @cache_readonly
#     729 def group_info(self) -> tuple[npt.NDArray[np.intp], npt.NDArray[np.intp], int]:
# --> 730     comp_ids, obs_group_ids = self._get_compressed_codes()
#     732     ngroups = len(obs_group_ids)
#     733     comp_ids = ensure_platform_int(comp_ids)
#
# File ~/code/Kaggle_/.testlgbm/lib/python3.10/site-packages/pandas/core/groupby/ops.py:754, in BaseGrouper._get_compressed_codes(self)
#     751     # FIXME: compress_group_index's second return value is int64, not intp
#     753 ping = self.groupings[0]
# --> 754 return ping.codes, np.arange(len(ping.group_index), dtype=np.intp)
#
# File ~/code/Kaggle_/.testlgbm/lib/python3.10/site-packages/pandas/core/groupby/grouper.py:691, in Grouping.codes(self)
#     689 @property
#     690 def codes(self) -> npt.NDArray[np.signedinteger]:
# --> 691     return self._codes_and_uniques[0]
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/code/Kaggle_/.testlgbm/lib/python3.10/site-packages/pandas/core/groupby/grouper.py:801, in Grouping._codes_and_uniques(self)
#     796     uniques = self._uniques
#     797 else:
#     798     # GH35667, replace dropna=False with use_na_sentinel=False
#     799     # error: Incompatible types in assignment (expression has type "Union[
#     800     # ndarray[Any, Any], Index]", variable has type "Categorical")
# --> 801     codes, uniques = algorithms.factorize(  # type: ignore[assignment]
#     802         self.grouping_vector, sort=self._sort, use_na_sentinel=self._dropna
#     803     )
#     804 return codes, uniques
#
# File ~/code/Kaggle_/.testlgbm/lib/python3.10/site-packages/pandas/core/algorithms.py:795, in factorize(values, sort, use_na_sentinel, size_hint)
#     792             # Don't modify (potentially user-provided) array
#     793             values = np.where(null_mask, na_value, values)
# --> 795     codes, uniques = factorize_array(
#     796         values,
#     797         use_na_sentinel=use_na_sentinel,
#     798         size_hint=size_hint,
#     799     )
#     801 if sort and len(uniques) > 0:
#     802     uniques, codes = safe_sort(
#     803         uniques,
#     804         codes,
#    (...)
#     807         verify=False,
#     808     )
#
# KeyboardInterrupt:

# %%
# Testing
if is_testing:
    testing_model = deepcopy(model)
    prepro_testing = deepcopy(prepro)

    df_train_feats = prepro_testing.fit_transform(df_train)
    df_test_feats = prepro_testing.transform(df_test)

    testing_model.fit(
        df_train_feats,
        df_train['target'],
            callbacks=[
                lgb.callback.log_evaluation(period=100),
            ],
        )
    test_score = score(testing_model,df_test_feats,  df_test['target'])
    print(test_score)

    if save_test_model:
        joblib.dump((testing_model, prepro_testing), model_filename_test)
# Out:
# 5.9469350761610835

# %%
# Final training
if is_train_final:

    prepro_final = deepcopy(prepro)
    final_model = deepcopy(model)

    df_feats = prepro_final.fit_transform(df)

    final_model.fit(
        df_feats,
        df['target'],
            callbacks=[
                lgb.callback.log_evaluation(period=100),
            ],
        )
    if save_final_model:
        joblib.dump((final_model, prepro_final), model_filename_final)

# %% [markdown]
# # **Submission**

# %%
models = joblib.load(model_filename_CV)
global_stock_id_feats_final = {
    "median_size": df.groupby("stock_id")["bid_size"].median() + df.groupby("stock_id")["ask_size"].median(),
    "std_size": df.groupby("stock_id")["bid_size"].std() + df.groupby("stock_id")["ask_size"].std(),
    "ptp_size": df.groupby("stock_id")["bid_size"].max() - df.groupby("stock_id")["bid_size"].min(),
    "median_price": df.groupby("stock_id")["bid_price"].median() + df.groupby("stock_id")["ask_price"].median(),
    "std_price": df.groupby("stock_id")["bid_price"].std() + df.groupby("stock_id")["ask_price"].std(),
    "ptp_price": df.groupby("stock_id")["bid_price"].max() - df.groupby("stock_id")["ask_price"].min(),
}

# %%
y_min, y_max = -64, 64
lgb_model_weights = weighted_average(models)
lgb_model_weights
# Out:
# [0.125, 0.125, 0.25, 0.5]

# %%
weighted_average(range(3))

for date in tqdm(np.sort(df_test.date_id.unique())):
        df_date = df_test[df_test.date_id==date]
        for sec in range(0, 541, 10):
            # Data setup
            test = df_date[df_date['seconds_in_bucket']==sec].copy()
            y_test = test['target']
            test.drop('target', axis=1, inplace=True)
            sample_prediction = pd.DataFrame({'target':np.nan}, index = test.index)

            pred = np.zeros(len(test))
            for model, weight in zip(models, lgb_model_weights):
                test_feat = generate_all_features(test, global_stock_id_feats_final)
                pred += weight * model.predict(test_feat)
            
            pred = pred - np.mean(pred)
            pred = np.clip(pred, y_min, y_max)

            sample_prediction['target'] = pred
            # break
        break
            # Submission model
            # X_test = preprocess.transform(test)
            # model.add_data() #TO MODIFY =======
            # sample_prediction['target'] = model.predict(X_test)
# Out:
#   0%|          | 0/45 [00:00<?, ?it/s]
#   0%|          | 0/45 [01:00<?, ?it/s]

# %%
test_feat[feature_columns]
# Out:
#      stock_id  seconds_in_bucket  imbalance_size  imbalance_buy_sell_flag  \
# 0           0                  0    0.000000e+00                        0
# 1           1                  0    1.378668e+06                        1
# 2           2                  0    0.000000e+00                        0
# 3           3                  0    7.863030e+06                        1
# 4           4                  0    4.599490e+06                       -1
# ..        ...                ...             ...                      ...
# 195       195                  0    5.944218e+06                        1
# 196       196                  0    2.441752e+06                        1
# 197       197                  0    4.641126e+05                       -1
# 198       198                  0    1.650333e+07                        1
# 199       199                  0    1.560027e+06                       -1
#
#      reference_price  matched_size  far_price  near_price  bid_price  \
# 0           1.000268   12874820.00        NaN         NaN   0.999911
# 1           0.999853    2806215.25        NaN         NaN   0.999853
# 2           0.999373    4873746.50        NaN         NaN   0.999373
# 3           0.999576   46879784.00        NaN         NaN   0.999576
# 4           1.000425   15193377.00        NaN         NaN   0.999952
# ..               ...           ...        ...         ...        ...
# 195         0.999566   16517714.00        NaN         NaN   0.999675
# 196         0.999332    3866432.00        NaN         NaN   0.999332
# 197         0.999984    2801073.25        NaN         NaN   0.999984
# 198         0.999477   68372056.00        NaN         NaN   0.999961
# 199         1.000243   11676746.00        NaN         NaN   0.999558
#
#          bid_size  ...  dow  seconds  minute  time_to_market_close  \
# 0    11182.000000  ...    1        0       0                   540
# 1      801.200012  ...    1        0       0                   540
# 2     8005.459961  ...    1        0       0                   540
# 3    21946.099609  ...    1        0       0                   540
# 4      169.009995  ...    1        0       0                   540
# ..            ...  ...  ...      ...     ...                   ...
# 195   9224.000000  ...    1        0       0                   540
# 196  16768.000000  ...    1        0       0                   540
# 197    171.699997  ...    1        0       0                   540
# 198   4134.000000  ...    1        0       0                   540
# 199  26513.599609  ...    1        0       0                   540
#
#      global_median_size  global_std_size  global_ptp_size  \
# 0          42739.160156    132986.919326     5.898989e+06
# 1          25548.500000     66444.908576     6.938986e+05
# 2          26228.099609     75674.654277     1.069838e+06
# 3          41667.000000     93875.770485     1.928848e+06
# 4          34014.580078     80670.274575     1.604066e+06
# ..                  ...              ...              ...
# 195        51941.548828     98218.034911     2.761659e+06
# 196        42476.951172     78070.064273     4.596574e+05
# 197        30070.040039     71964.174970     1.575294e+06
# 198       304739.250000    354682.788090     2.159163e+06
# 199       114127.101562    194210.056872     4.564502e+06
#
#      global_median_price  global_std_price  global_ptp_price
# 0               1.999695          0.003353          0.017414
# 1               1.999827          0.005588          0.029370
# 2               2.000200          0.005333          0.051622
# 3               1.999980          0.002903          0.018551
# 4               1.999816          0.003717          0.017379
# ..                   ...               ...               ...
# 195             1.999930          0.003051          0.014076
# 196             2.000042          0.003416          0.017398
# 197             1.999984          0.004696          0.020387
# 198             1.999917          0.003146          0.015738
# 199             2.000128          0.004325          0.022793
#
# [200 rows x 160 columns]

# %%
test_feat
# Out:
#      stock_id  seconds_in_bucket  imbalance_size  imbalance_buy_sell_flag  \
# 0           0                  0    0.000000e+00                        0
# 1           1                  0    1.378668e+06                        1
# 2           2                  0    0.000000e+00                        0
# 3           3                  0    7.863030e+06                        1
# 4           4                  0    4.599490e+06                       -1
# ..        ...                ...             ...                      ...
# 195       195                  0    5.944218e+06                        1
# 196       196                  0    2.441752e+06                        1
# 197       197                  0    4.641126e+05                       -1
# 198       198                  0    1.650333e+07                        1
# 199       199                  0    1.560027e+06                       -1
#
#      reference_price  matched_size  far_price  near_price  bid_price  \
# 0           1.000268   12874820.00        NaN         NaN   0.999911
# 1           0.999853    2806215.25        NaN         NaN   0.999853
# 2           0.999373    4873746.50        NaN         NaN   0.999373
# 3           0.999576   46879784.00        NaN         NaN   0.999576
# 4           1.000425   15193377.00        NaN         NaN   0.999952
# ..               ...           ...        ...         ...        ...
# 195         0.999566   16517714.00        NaN         NaN   0.999675
# 196         0.999332    3866432.00        NaN         NaN   0.999332
# 197         0.999984    2801073.25        NaN         NaN   0.999984
# 198         0.999477   68372056.00        NaN         NaN   0.999961
# 199         1.000243   11676746.00        NaN         NaN   0.999558
#
#          bid_size  ...  dow  seconds  minute  time_to_market_close  \
# 0    11182.000000  ...    1        0       0                   540
# 1      801.200012  ...    1        0       0                   540
# 2     8005.459961  ...    1        0       0                   540
# 3    21946.099609  ...    1        0       0                   540
# 4      169.009995  ...    1        0       0                   540
# ..            ...  ...  ...      ...     ...                   ...
# 195   9224.000000  ...    1        0       0                   540
# 196  16768.000000  ...    1        0       0                   540
# 197    171.699997  ...    1        0       0                   540
# 198   4134.000000  ...    1        0       0                   540
# 199  26513.599609  ...    1        0       0                   540
#
#      global_median_size  global_std_size  global_ptp_size  \
# 0          42739.160156    132986.919326     5.898989e+06
# 1          25548.500000     66444.908576     6.938986e+05
# 2          26228.099609     75674.654277     1.069838e+06
# 3          41667.000000     93875.770485     1.928848e+06
# 4          34014.580078     80670.274575     1.604066e+06
# ..                  ...              ...              ...
# 195        51941.548828     98218.034911     2.761659e+06
# 196        42476.951172     78070.064273     4.596574e+05
# 197        30070.040039     71964.174970     1.575294e+06
# 198       304739.250000    354682.788090     2.159163e+06
# 199       114127.101562    194210.056872     4.564502e+06
#
#      global_median_price  global_std_price  global_ptp_price
# 0               1.999695          0.003353          0.017414
# 1               1.999827          0.005588          0.029370
# 2               2.000200          0.005333          0.051622
# 3               1.999980          0.002903          0.018551
# 4               1.999816          0.003717          0.017379
# ..                   ...               ...               ...
# 195             1.999930          0.003051          0.014076
# 196             2.000042          0.003416          0.017398
# 197             1.999984          0.004696          0.020387
# 198             1.999917          0.003146          0.015738
# 199             2.000128          0.004325          0.022793
#
# [200 rows x 160 columns]

# %%
pred
# Out:
# array([ 0.00372014,  0.12091547, -0.2335647 , -0.20005453,  0.28919267,
#        -0.07303482, -0.24893318, -0.35595845, -0.12437316, -0.2335647 ,
#         0.05778488,  0.39755979,  0.01802448,  0.36466701,  0.22805028,
#        -0.23845915,  0.39754376, -0.11948629,  0.02879339,  0.38217582,
#        -0.14783484, -0.14114001,  0.33601693, -0.14783484, -0.14783484,
#        -0.14783484,  0.05033691, -0.14866659, -0.20659555, -0.2335647 ,
#         0.0515903 , -0.15154023,  0.08667565, -0.00783628,  0.24518352,
#        -0.29399148, -0.05993284, -0.35595845, -0.30333634, -0.145917  ,
#        -0.00637755, -0.14590054,  0.2941225 ,  0.03869534, -0.35595845,
#        -0.06573168,  0.37235659, -0.13035243, -0.01152377,  0.0456894 ,
#         0.20504763, -0.01500222, -0.11235186, -0.0270448 , -0.35595845,
#         0.08469761,  0.30408525,  0.3355455 ,  0.04976161,  0.38313664,
#         0.11255045, -0.06410775,  0.40448684,  0.08137458,  0.40448684,
#        -0.0018346 , -0.35595845, -0.13278826, -0.35595845, -0.00925883,
#         0.19362048,  0.18103557, -0.01028374, -0.04567393, -0.07303482,
#         0.13208929, -0.06874924, -0.29399148, -0.11283183,  0.04794845,
#         0.26044406, -0.1981398 , -0.12438056,  0.02804085,  0.00862813,
#         0.23235978, -0.14783484,  0.25529766, -0.35595845, -0.35595845,
#         0.21965238,  0.06820939,  0.01269794,  0.01269794, -0.35595845,
#         0.06201582,  0.32494649,  0.25793044,  0.00405867,  0.00248011,
#        -0.35595845, -0.35099127,  0.3141953 ,  0.01141541, -0.04567393,
#        -0.00244893,  0.21965238, -0.35595845,  0.20347332,  0.02189501,
#        -0.35595845, -0.11320714, -0.00244893, -0.14783484,  0.29375388,
#         0.40448684,  0.14231487, -0.10459103, -0.2737299 ,  0.25478999,
#        -0.00757743,  0.02645573, -0.23904329,  0.07216092, -0.30407494,
#        -0.29399148,  0.19208076,  0.26969332,  0.23235978, -0.00631147,
#        -0.0809459 ,  0.03919682, -0.04567393, -0.15447137,  0.06815634,
#        -0.09520026,  0.09065575, -0.1054169 ,  0.13232639, -0.11001813,
#         0.16548565, -0.01500222,  0.22541671, -0.15316849, -0.12804531,
#        -0.01500222,  0.00332804, -0.18685448, -0.06368412,  0.00332804,
#         0.18536168,  0.03098232,  0.36934167,  0.11386378, -0.03135414,
#        -0.08919677, -0.33394475, -0.01028374,  0.14721338,  0.20347332,
#         0.01145791, -0.09311858, -0.35595845,  0.21965238,  0.11359534,
#        -0.07029766, -0.12624494, -0.08939685,  0.02715546,  0.14775537,
#         0.00862813, -0.01315677, -0.17560961, -0.35595845, -0.17560961,
#        -0.03135414,  0.26044406, -0.14114001, -0.01028374,  0.06478272,
#         0.22639783, -0.2556752 , -0.04567393, -0.01180841,  0.15445876,
#         0.38285387,  0.12695103,  0.00477513,  0.12740835, -0.11286045,
#         0.39755979,  0.11316719, -0.2335647 , -0.03669613,  0.14271919,
#        -0.01500222, -0.04567393,  0.27772918,  0.01968435, -0.01315677])

# %%
if is_infer:
    import optiver2023
    env = optiver2023.make_env()
    iter_test = env.iter_test()
    counter = 0
    y_min, y_max = -64, 64
    qps, predictions = [], []
    cache = pd.DataFrame()

    # Weights for each fold model
    if LGB:
        lgb_model_weights = weighted_average(models)
        #cbt_model_weights = weighted_average(models_cbt)
    
    for (test, revealed_targets, sample_prediction) in iter_test:
        now_time = time.time()
        cache = pd.concat([cache, test], ignore_index=True, axis=0)
        if counter > 0:
            cache = cache.groupby(['stock_id']).tail(21).sort_values(by=['date_id', 'seconds_in_bucket', 'stock_id']).reset_index(drop=True)
        feat = generate_all_features(cache)[-len(test):]
        print(f"Feat Shape is: {feat.shape}")

        # Generate predictions for each model and calculate the weighted average
        if LGB:
            lgb_predictions = np.zeros(len(test))
            for model, weight in zip(models, lgb_model_weights):
                lgb_predictions += weight * model.predict(feat[feature_columns])

        predictions = lgb_predictions
        
        #Using mean predictions rather than zero sum
        final_predictions = predictions - np.mean(predictions)
        clipped_predictions = np.clip(final_predictions, y_min, y_max)
        sample_prediction['target'] = clipped_predictions
        env.predict(sample_prediction)
        counter += 1
        qps.append(time.time() - now_time)
        if counter % 10 == 0:
            print(counter, 'qps:', np.mean(qps))

    time_cost = 1.146 * np.mean(qps)
    print(f"The code will take approximately {np.round(time_cost, 4)} hours to reason about")
